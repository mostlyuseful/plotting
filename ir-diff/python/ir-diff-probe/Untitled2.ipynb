# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

xx = [50,50,50,   125,125,125, 200,200,200]
yy = [50,125,200, 50,125,200,  50,125,200]
zz = [2.8671875, 2.1162109375, 2.3740234375, 2.6640625, 2.6865234375, 2.6240234375, 3.9990234375, 2.7451171875, 2.8115234375]

ax.plot_trisurf(xx,yy,zz)
ax.view_init(0, 0)
xlim(0,200)
ylim(0,200)
ax.set_zlim(0,5)
# Out:
# (0, 5)

# %%
# Out:
# (0, 5)
