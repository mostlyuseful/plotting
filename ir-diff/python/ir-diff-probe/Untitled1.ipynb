# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
np.set_printoptions(suppress=True)

# %%
table = np.loadtxt('log.txt', delimiter=';')
table_dt = table.copy()
table_dt[:, 0] -= table[0,0]
table_dt.shape
# Out:
# (6806, 4)

# %%
figure(figsize=(10,3))
#plot(table_dt[:,1], label='ambient')
plot(table_dt[:,2], label='far')
plot(table_dt[:,3], label='near')
legend();

# %%
ambient, near, far = table_dt[:,1:4].T

# %%
plot(far-near)
hlines(0,0,7000)
plot(100*((far>100) & (near>100)))
