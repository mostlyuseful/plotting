# %%
# %pylab inline
import io
import subprocess
import pathlib
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from plotting import svg2lines as s2l

# %%
path_coll = s2l.parse_pltme(s2l.convert_svg_to_pltme('../plotting/plotting/filled_triangle.svg')).scale(0.3)

# %%
figure()
for path in path_coll.paths:
    plot(path.x, path.y)

# %%
path_coll.paths[1]
